# %%
import os
import torch
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
import mpcr_pose_tools as pose
import mpcr_pose_tools.video as pose_video

# %%
pose.name
# Out:
# 'mpcr_pose_tools'

# %%
dir(pose)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'name',
#  'video']

# %%
dir(pose_video)
# Out:
# ['ChannelsFirst',
#  'ChannelsLast',
#  'Dataset',
#  'F',
#  'Rescale',
#  'Resize',
#  'VideoFolder',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'np',
#  'os',
#  'pims',
#  'torch']

# %%
base_dir = "/external/data/videos/HMDB-example/Videos_Pose/Black_Pose/"

# %%
os.listdir(base_dir)
# Out:
# ['brush_hair', 'cartwheel']

# %%
transform = transforms.Compose([
    pose_video.ChannelsFirst(),
    pose_video.Rescale(1 / 255.0),
    pose_video.Resize((100, 100)),
    pose_video.ChannelsLast(),
])

# %%
dataset = pose_video.VideoFolder(base_dir, 10, transform=transform)
len(dataset)
# Out:
# 90

# %%
dataset.classes
# Out:
# {0: 'brush_hair', 1: 'cartwheel'}

# %%
for i in range(len(dataset)):
    chunk, label = dataset[i]
    plt.imshow(chunk[9])
    plt.show()
    print(chunk.shape, dataset.classes[label])
# Out:
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# torch.Size([10, 100, 100, 3]) brush_hair
# ...
